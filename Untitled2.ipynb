# %%
from myfunctions import *

# %%
df = new_df('2704_w1-2.xlsx')

# %%
df
# Out:
#                      Apotekvarer  Asiatisk mat  Aviser/ukeblader  \
# tnr
# 270420230201168312           0.0           0.0               0.0
# 270420230201168313           0.0           0.0               0.0
# 270420230201168314           0.0           0.0               0.0
# 270420230201168315           0.0           0.0               1.0
# 270420230201168316           0.0           0.0               0.0
# ...                          ...           ...               ...
# 2704202301141635340          0.0           0.0               0.0
# 2704202301141635341          0.0           0.0               0.0
# 2704202301141635342          0.0           0.0               0.0
# 2704202301141635343          0.0           0.0               0.0
# 2704202301141635344          0.0           0.0               0.0
#
#                      Baby og barneartikle  Bacon, kjøl  Bakevarer  \
# tnr
# 270420230201168312                    0.0          0.0        0.0
# ...

# %%
pca_df_1 = pca_reduction(df, 2)
umap_df_1 = umap_reduction(df, 2)
tsne_df_1 = tsne_reduction(df, 2)
svd_df_1 = svd_reduction(df, 2)
# Out:
# 0.30
# 47.40
# 116.11
# 0.13

# %%
plt.scatter(pca_df_1[:,0], pca_df_1[:,1])

# %%
plt.scatter(umap_df_1[:,0], umap_df_1[:,1])

# %%
plt.scatter(tsne_df_1[:,0], tsne_df_1[:,1])

# %%
plt.scatter(svd_df_1[:,0], svd_df_1[:,1])

# %%
gap_stat(pca_df_1)
# Out:
# Optimal clusters:  4
#    n_clusters  gap_value  ref_dispersion_std        sk          gap*  \
# 0         2.0   8.332740        44734.388871  0.002372  2.556609e+07
# 1         3.0   8.336090       100692.786987  0.005336  2.560447e+07
# 2         4.0   8.340002       143816.015964  0.007623  2.561679e+07
# 3         5.0   8.336509        42098.583287  0.002228  2.562416e+07
# 4         6.0   8.329302        57814.075970  0.003076  2.550354e+07
# 5         7.0   8.330647       185930.144784  0.009887  2.552724e+07
# 6         8.0   8.331404       129511.485144  0.006866  2.554095e+07
#
#             sk*      diff         diff*
# 0  2.952120e+07  0.001986  2.952726e+07
# 1  2.956565e+07  0.003712  2.956771e+07
# 2  2.958003e+07  0.005721  2.958089e+07
# 3  2.958826e+07  0.010283  2.956962e+07
# 4  2.944900e+07  0.008542  2.945313e+07
# 5  2.947683e+07  0.006110  2.947869e+07
# 6  2.949240e+07       NaN           NaN

# %%
gap_stat(umap_df_1)
# Out:
# Optimal clusters:  8
#    n_clusters  gap_value  ref_dispersion_std        sk          gap*  \
# 0         2.0   1.408629        17213.493292  0.004152  3.514844e+06
# 1         3.0   1.410999        26289.308890  0.006327  3.523826e+06
# 2         4.0   1.411132         9316.851654  0.002245  3.523832e+06
# 3         5.0   1.407777        36979.680590  0.008918  3.510670e+06
# 4         6.0   1.406989        24488.264713  0.005914  3.507566e+06
# 5         7.0   1.410409         1633.092066  0.000394  3.519782e+06
# 6         8.0   1.414059        15487.869077  0.003721  3.534781e+06
#
#             sk*      diff         diff*
# 0  4.058624e+06  0.003957  4.060057e+06
# 1  4.069039e+06  0.002112  4.068974e+06
# 2  4.068980e+06  0.012273  4.067085e+06
# 3  4.053923e+06  0.006702  4.053358e+06
# 4  4.050254e+06 -0.003026  4.052079e+06
# 5  4.064294e+06  0.000072  4.066640e+06
# 6  4.081640e+06       NaN           NaN

# %%
gap_stat(tsne_df_1)
# Out:
# Optimal clusters:  6
#    n_clusters  gap_value  ref_dispersion_std        sk          gap*  \
# 0         2.0   0.782552        1.127775e+06  0.006598  9.720773e+07
# 1         3.0   0.789130        3.177805e+05  0.001853  9.826106e+07
# 2         4.0   0.781863        1.198486e+06  0.007035  9.709115e+07
# 3         5.0   0.785070        5.575559e+05  0.003259  9.759524e+07
# 4         6.0   0.793775        8.343975e+05  0.004866  9.866584e+07
# 5         7.0   0.786676        7.300033e+05  0.004262  9.784943e+07
# 6         8.0   0.789689        5.986695e+05  0.003493  9.833200e+07
#
#             sk*      diff         diff*
# 0  1.122509e+08 -0.004725  1.124092e+08
# 1  1.134625e+08  0.014302  1.132868e+08
# 2  1.121169e+08  0.000053  1.121904e+08
# 3  1.126945e+08 -0.003840  1.128616e+08
# 4  1.139322e+08  0.011361  1.138053e+08
# 5  1.129889e+08  0.000480  1.130628e+08
# 6  1.135454e+08       NaN           NaN

# %%
gap_stat(svd_df_1)
# Out:
# Optimal clusters:  4
#    n_clusters  gap_value  ref_dispersion_std        sk          gap*  \
# 0         2.0   8.043866        68176.967174  0.004091  2.257932e+07
# 1         3.0   8.177520       139735.331479  0.008350  2.272340e+07
# 2         4.0   8.181995       180761.586972  0.010731  2.278307e+07
# 3         5.0   8.174920       178414.565075  0.010675  2.267715e+07
# 4         6.0   8.179064       125103.377554  0.007463  2.273286e+07
# 5         7.0   8.176755       177746.740715  0.010635  2.270611e+07
# 6         8.0   8.179396       116309.191736  0.006943  2.273840e+07
#
#             sk*      diff         diff*
# 0  2.607243e+07 -0.125304  2.609497e+07
# 1  2.623905e+07  0.006255  2.624850e+07
# 2  2.630817e+07  0.017750  2.629177e+07
# 3  2.618585e+07  0.003320  2.619420e+07
# 4  2.624991e+07  0.012943  2.624604e+07
# 5  2.621929e+07  0.004303  2.622398e+07
# 6  2.625627e+07       NaN           NaN

# %%
silhouette_analysis(pca_df_1)
# Out:
# For n_clusters = 2, the average silhouette_score is : 0.7459
# For n_clusters = 3, the average silhouette_score is : 0.6959
# For n_clusters = 4, the average silhouette_score is : 0.6934
# For n_clusters = 5, the average silhouette_score is : 0.7109
# For n_clusters = 6, the average silhouette_score is : 0.6734
# For n_clusters = 7, the average silhouette_score is : 0.7126
# For n_clusters = 8, the average silhouette_score is : 0.7134

# %%
silhouette_analysis(umap_df_1)
# Out:
# For n_clusters = 2, the average silhouette_score is : 0.4556
# For n_clusters = 3, the average silhouette_score is : 0.4357
# For n_clusters = 4, the average silhouette_score is : 0.3442
# For n_clusters = 5, the average silhouette_score is : 0.3785
# For n_clusters = 6, the average silhouette_score is : 0.4202
# For n_clusters = 7, the average silhouette_score is : 0.4175
# For n_clusters = 8, the average silhouette_score is : 0.4037

# %%
silhouette_analysis(tsne_df_1)
# Out:
# For n_clusters = 2, the average silhouette_score is : 0.3515
# For n_clusters = 3, the average silhouette_score is : 0.3735
# For n_clusters = 4, the average silhouette_score is : 0.3755
# For n_clusters = 5, the average silhouette_score is : 0.3461
# For n_clusters = 6, the average silhouette_score is : 0.3728
# For n_clusters = 7, the average silhouette_score is : 0.3669
# For n_clusters = 8, the average silhouette_score is : 0.3527

# %%
silhouette_analysis(svd_df_1)
# Out:
# For n_clusters = 2, the average silhouette_score is : 0.7301
# For n_clusters = 3, the average silhouette_score is : 0.6655
# For n_clusters = 4, the average silhouette_score is : 0.6717
# For n_clusters = 5, the average silhouette_score is : 0.6636
# For n_clusters = 6, the average silhouette_score is : 0.6241
# For n_clusters = 7, the average silhouette_score is : 0.6151
# For n_clusters = 8, the average silhouette_score is : 0.6169

# %%
db_score(pca_df_1)
# Out:
# For n_clusters = 2, the DB-score is : 0.5931
# For n_clusters = 3, the DB-score is : 0.6646
# For n_clusters = 4, the DB-score is : 0.4928
# For n_clusters = 5, the DB-score is : 0.5023
# For n_clusters = 6, the DB-score is : 0.5361
# For n_clusters = 7, the DB-score is : 0.5533
# For n_clusters = 8, the DB-score is : 0.5714

# %%
db_score(umap_df_1)
# Out:
# For n_clusters = 2, the DB-score is : 1.0016
# For n_clusters = 3, the DB-score is : 0.9210
# For n_clusters = 4, the DB-score is : 0.9605
# For n_clusters = 5, the DB-score is : 0.8662
# For n_clusters = 6, the DB-score is : 0.7520
# For n_clusters = 7, the DB-score is : 0.7509
# For n_clusters = 8, the DB-score is : 0.8056

# %%
db_score(tsne_df_1)
# Out:
# For n_clusters = 2, the DB-score is : 1.1775
# For n_clusters = 3, the DB-score is : 0.8889
# For n_clusters = 4, the DB-score is : 0.8280
# For n_clusters = 5, the DB-score is : 0.9107
# For n_clusters = 6, the DB-score is : 0.7923
# For n_clusters = 7, the DB-score is : 0.8028
# For n_clusters = 8, the DB-score is : 0.8520

# %%
db_score(svd_df_1)
# Out:
# For n_clusters = 2, the DB-score is : 0.6018
# For n_clusters = 3, the DB-score is : 0.6883
# For n_clusters = 4, the DB-score is : 0.6829
# For n_clusters = 5, the DB-score is : 0.5536
# For n_clusters = 6, the DB-score is : 0.5854
# For n_clusters = 7, the DB-score is : 0.5994
# For n_clusters = 8, the DB-score is : 0.6215

# %%
elbow_method(pca_df_1)

# %%
elbow_method(umap_df_1)

# %%
elbow_method(tsne_df_1)

# %%
elbow_method(svd_df_1)

# %%
i = range(0, 10)
for avg in i:
    pca_reduction(df, 2)
# Out:
# 0.16
# 0.16
# 0.16
# 0.15
# 0.16
# 0.15
# 0.15
# 0.15
# 0.17
# 0.17

# %%
i = range(0, 10)
for avg in i:
    umap_reduction(df, 2)
# Out:
# 47.12
# 34.41
# 34.22
# 34.18
# 33.97
# 34.12
# 33.99
# 34.24
# 33.93
# 34.07

# %%
i = range(0, 10)
for avg in i:
    tsne_reduction(df, 2)
# Out:
# 30.0
# 104.97
# 30.0
# 102.23
# 30.0
# 101.11
# 30.0
# 101.18
# 30.0
# 101.66
# 30.0
# 102.06
# 30.0
# 104.47
# 30.0
# 110.20
# 30.0
# 123.78
# 30.0
# 118.31

# %%
i = range(0, 10)
for avg in i:
    svd_reduction(df, 2)
# Out:
# 0.14
# 0.13
# 0.13
# 0.13
# 0.13
# 0.13
# 0.13
# 0.13
# 0.13
# 0.13

# %%
ch_review(pca_df_1)

# %%
ch_review(umap_df_1)

# %%
ch_review(tsne_df_1)

# %%
ch_review(svd_df_1)

# %%
# Gap Statistic for K means

def optimalK(data, nrefs=3, maxClusters=15):
    """
    Calculates KMeans optimal K using Gap Statistic 
    Params:
        data: ndarry of shape (n_samples, n_features)
        nrefs: number of sample reference datasets to create
        maxClusters: Maximum number of clusters to test for
    Returns: (gaps, optimalK)
    """
    gaps = np.zeros((len(range(1, maxClusters)),))
    resultsdf = pd.DataFrame({'clusterCount':[], 'gap':[]})
    for gap_index, k in enumerate(range(1, maxClusters)):
# Holder for reference dispersion results
        refDisps = np.zeros(nrefs)
# For n references, generate random sample and perform kmeans getting resulting dispersion of each loop
        for i in range(nrefs):
            
            # Create new random reference set
            randomReference = np.random.random_sample(size=data.shape)
            
            # Fit to it
            km = KMeans(k)
            km.fit(randomReference)
            
            refDisp = km.inertia_
            refDisps[i] = refDisp
# Fit cluster to original data and create dispersion
        km = KMeans(k)
        km.fit(data)
        
        origDisp = km.inertia_
        # Calculate gap statistic
        gap = np.log(np.mean(refDisps)) - np.log(origDisp)
        # Assign this loop's gap statistic to gaps
        gaps[gap_index] = gap
        
        resultsdf = resultsdf.append({'clusterCount':k, 'gap':gap}, ignore_index=True)
    return (gaps.argmax() + 1, resultsdf)

score_g, df = optimalK(pca_df_1, nrefs=5, maxClusters=8)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K');

# %%
score_g, df = optimalK(umap_df_1, nrefs=5, maxClusters=8)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K');

# %%
score_g, df = optimalK(tsne_df_1, nrefs=5, maxClusters=8)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K');

# %%
score_g, df = optimalK(svd_df_1, nrefs=5, maxClusters=8)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K');
